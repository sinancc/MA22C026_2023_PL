# %% [markdown]
# #Importing necessary modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import urllib
import shutil
# %matplotlib inline

# %% [markdown]
# #Importing Data Required

# %%
# Download and preprocess COVID-19 data from JHU-CSSE
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
url2= 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'

# %% [markdown]
# #Essential data Munging

# %%
data = pd.read_csv(url)
data.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...   209322  209340  209358  209362
# 1        0        0        0        0  ...   334391  334408  334408  334427
# 2        0        0        0        0  ...   271441  271448  271463  271469
# 3        0        0        0        0  ...    47866   47875   47875   47875
# 4        0        0        0        0  ...   105255  105277  105277  105277
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0  209369  209390  209406  209436  209451  209451
# 1  334427  334427  334427  334427  334443  334457
# 2  271469  271477  271477  271490  271494  271496
# 3   47875   47875   47875   47875   47890   47890
# 4  105277  105277  105277  105277  105288  105288
#
# [5 rows x 1147 columns]

# %%
data2=pd.read_csv(url2)
data2.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  3/5/23  \
# 0  32.539527 -86.644082  ...   19732   19759   19759   19759   19759   19759
# 1  30.727750 -87.722071  ...   69641   69767   69767   69767   69767   69767
# 2  31.868263 -85.387129  ...    7451    7474    7474    7474    7474    7474
# 3  32.996421 -87.125115  ...    8067    8087    8087    8087    8087    8087
# 4  33.982109 -86.567906  ...   18616   18673   18673   18673   18673   18673
#
#    3/6/23  3/7/23  3/8/23  3/9/23
# 0   19759   19759   19790   19790
# 1   69767   69767   69860   69860
# 2    7474    7474    7485    7485
# 3    8087    8087    8091    8091
# 4   18673   18673   18704   18704
#
# [5 rows x 1154 columns]

# %%
# Drop un necessary columns  in the DataFrame
data2= data2.rename(columns={'iso3': 'iso_a3'})
columns_to_drop = ['UID', 'iso2', 'code3', 'FIPS', 'Admin2' ,'Combined_Key','Lat','Long_']
data2 = data2.drop(columns=[col for col in columns_to_drop if col in data2.columns])

# %%
data2.head()
# Out:
#   iso_a3 Province_State Country_Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0    USA        Alabama             US        0        0        0        0
# 1    USA        Alabama             US        0        0        0        0
# 2    USA        Alabama             US        0        0        0        0
# 3    USA        Alabama             US        0        0        0        0
# 4    USA        Alabama             US        0        0        0        0
#
#    1/26/20  1/27/20  1/28/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  \
# 0        0        0        0  ...    19732   19759   19759   19759   19759
# 1        0        0        0  ...    69641   69767   69767   69767   69767
# 2        0        0        0  ...     7451    7474    7474    7474    7474
# 3        0        0        0  ...     8067    8087    8087    8087    8087
# 4        0        0        0  ...    18616   18673   18673   18673   18673
#
#    3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0   19759   19759   19759   19790   19790
# 1   69767   69767   69767   69860   69860
# 2    7474    7474    7474    7485    7485
# 3    8087    8087    8087    8091    8091
# 4   18673   18673   18673   18704   18704
#
# [5 rows x 1146 columns]

# %%
data2=data2.groupby('iso_a3').sum()
data2.head()
# Out:
# <ipython-input-310-5f28b9dcf9d0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data2=data2.groupby('iso_a3').sum()
#         1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# iso_a3
# ASM           0        0        0        0        0        0        0
# GUM           0        0        0        0        0        0        0
# MNP           0        0        0        0        0        0        0
# PRI           0        0        0        0        0        0        0
# USA           1        1        2        2        5        5        5
#
#         1/29/20  1/30/20  1/31/20  ...    2/28/23     3/1/23     3/2/23  \
# iso_a3                             ...
# ASM           0        0        0  ...       8320       8320       8320
# GUM           0        0        0  ...      60989      60997      61001
# MNP           0        0        0  ...      13631      13631      13631
# PRI           0        0        0  ...    1098242    1098678    1099150
# USA           6        6        8  ...  102237507  102327472  102382876
#
#            3/3/23     3/4/23     3/5/23     3/6/23     3/7/23     3/8/23  \
# iso_a3
# ASM          8320       8320       8320       8320       8320       8320
# GUM         61002      61002      61002      61002      61018      61019
# MNP         13666      13666      13666      13666      13666      13666
# PRI       1099611    1099960    1100358    1100557    1100634    1101027
# USA     102441311  102443109  102438849  102447202  102482477  102546941
#
#            3/9/23
# iso_a3
# ASM          8320
# GUM         61027
# MNP         13666
# PRI       1101469
# USA     102593407
#
# [5 rows x 1143 columns]

# %%
data2= data2.rename(columns={'iso3': 'iso_a3'})

# %%
data2.head()
# Out:
#         1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# iso_a3
# ASM           0        0        0        0        0        0        0
# GUM           0        0        0        0        0        0        0
# MNP           0        0        0        0        0        0        0
# PRI           0        0        0        0        0        0        0
# USA           1        1        2        2        5        5        5
#
#         1/29/20  1/30/20  1/31/20  ...    2/28/23     3/1/23     3/2/23  \
# iso_a3                             ...
# ASM           0        0        0  ...       8320       8320       8320
# GUM           0        0        0  ...      60989      60997      61001
# MNP           0        0        0  ...      13631      13631      13631
# PRI           0        0        0  ...    1098242    1098678    1099150
# USA           6        6        8  ...  102237507  102327472  102382876
#
#            3/3/23     3/4/23     3/5/23     3/6/23     3/7/23     3/8/23  \
# iso_a3
# ASM          8320       8320       8320       8320       8320       8320
# GUM         61002      61002      61002      61002      61018      61019
# MNP         13666      13666      13666      13666      13666      13666
# PRI       1099611    1099960    1100358    1100557    1100634    1101027
# USA     102441311  102443109  102438849  102447202  102482477  102546941
#
#            3/9/23
# iso_a3
# ASM          8320
# GUM         61027
# MNP         13666
# PRI       1101469
# USA     102593407
#
# [5 rows x 1143 columns]

# %%
len(data2)
# Out:
# 6

# %%
# make a geometry object from Lat, Long
geo = gpd.points_from_xy(data['Long'], data['Lat'])
# give the geometry to geopandas together with data
gdata = gpd.GeoDataFrame(data, geometry=geo)
gdata.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  3/1/23  3/2/23  3/3/23  3/4/23  \
# 0        0        0        0        0  ...  209340  209358  209362  209369
# 1        0        0        0        0  ...  334408  334408  334427  334427
# 2        0        0        0        0  ...  271448  271463  271469  271469
# 3        0        0        0        0  ...   47875   47875   47875   47875
# 4        0        0        0        0  ...  105277  105277  105277  105277
#
#    3/5/23  3/6/23  3/7/23  3/8/23  3/9/23                    geometry
# 0  209390  209406  209436  209451  209451   POINT (67.70995 33.93911)
# 1  334427  334427  334427  334443  334457   POINT (20.16830 41.15330)
# 2  271477  271477  271490  271494  271496    POINT (1.65960 28.03390)
# 3   47875   47875   47875   47890   47890    POINT (1.52180 42.50630)
# 4  105277  105277  105277  105288  105288  POINT (17.87390 -11.20270)
#
# [5 rows x 1148 columns]

# %% [markdown]
# #importing shapefile

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world= world.rename(columns={'name': 'Country/Region'})
world.head()
# Out:
# <ipython-input-315-9d1c6046608b>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#        pop_est      continent            Country/Region iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
countries=world['Country/Region']

# %%
world.plot()
# Out:
# <Axes: >

# %%
# gdata=gdata[gdata['Country/Region'].isin(countries)]
# len(gdata)

# %%
gdata.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  3/1/23  3/2/23  3/3/23  3/4/23  \
# 0        0        0        0        0  ...  209340  209358  209362  209369
# 1        0        0        0        0  ...  334408  334408  334427  334427
# 2        0        0        0        0  ...  271448  271463  271469  271469
# 3        0        0        0        0  ...   47875   47875   47875   47875
# 4        0        0        0        0  ...  105277  105277  105277  105277
#
#    3/5/23  3/6/23  3/7/23  3/8/23  3/9/23                    geometry
# 0  209390  209406  209436  209451  209451   POINT (67.70995 33.93911)
# 1  334427  334427  334427  334443  334457   POINT (20.16830 41.15330)
# 2  271477  271477  271490  271494  271496    POINT (1.65960 28.03390)
# 3   47875   47875   47875   47890   47890    POINT (1.52180 42.50630)
# 4  105277  105277  105277  105288  105288  POINT (17.87390 -11.20270)
#
# [5 rows x 1148 columns]

# %%
country_data_covid = gdata.groupby('Country/Region').sum()
# Out:
# <ipython-input-320-b4f5f768f5e1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   country_data_covid = gdata.groupby('Country/Region').sum()

# %%
len(country_data_covid)
# Out:
# 201

# %%
country_data_covid.head()
# Out:
#                      Lat       Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan     33.93911  67.709953        0        0        0        0
# Albania         41.15330  20.168300        0        0        0        0
# Algeria         28.03390   1.659600        0        0        0        0
# Andorra         42.50630   1.521800        0        0        0        0
# Angola         -11.20270  17.873900        0        0        0        0
#
#                 1/26/20  1/27/20  1/28/20  1/29/20  ...  2/28/23  3/1/23  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...   209322  209340
# Albania               0        0        0        0  ...   334391  334408
# Algeria               0        0        0        0  ...   271441  271448
# Andorra               0        0        0        0  ...    47866   47875
# Angola                0        0        0        0  ...   105255  105277
#
#                 3/2/23  3/3/23  3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# Country/Region
# Afghanistan     209358  209362  209369  209390  209406  209436  209451  209451
# Albania         334408  334427  334427  334427  334427  334427  334443  334457
# Algeria         271463  271469  271469  271477  271477  271490  271494  271496
# Andorra          47875   47875   47875   47875   47875   47875   47890   47890
# Angola          105277  105277  105277  105277  105277  105277  105288  105288
#
# [5 rows x 1145 columns]

# %%
latest_data = pd.merge(world,country_data_covid, on='Country/Region',how='outer')

# %%
latest_data.head()
# Out:
#        pop_est      continent            Country/Region iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI      5496.0
# 1   58005463.0         Africa                  Tanzania    TZA     63177.0
# 2     603253.0         Africa                 W. Sahara    ESH       907.0
# 3   37589262.0  North America                    Canada    CAN   1736425.0
# 4  328239523.0  North America  United States of America    USA  21433226.0
#
#                                             geometry         Lat         Long  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  -17.713400   178.065000
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...   -6.369028    34.888822
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...         NaN          NaN
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...  708.855600 -1202.597900
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...         NaN          NaN
#
#    1/22/20  1/23/20  ...    2/28/23     3/1/23     3/2/23     3/3/23  \
# 0      0.0      0.0  ...    68889.0    68889.0    68897.0    68897.0
# 1      0.0      0.0  ...    42823.0    42846.0    42846.0    42846.0
# 2      NaN      NaN  ...        NaN        NaN        NaN        NaN
# 3      0.0      2.0  ...  4602806.0  4603795.0  4608456.0  4609042.0
# 4      NaN      NaN  ...        NaN        NaN        NaN        NaN
#
#       3/4/23     3/5/23     3/6/23     3/7/23     3/8/23     3/9/23
# 0    68897.0    68897.0    68897.0    68897.0    68897.0    68898.0
# 1    42846.0    42846.0    42846.0    42846.0    42906.0    42906.0
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3  4609458.0  4609751.0  4611428.0  4612219.0  4613054.0  4617095.0
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
# [5 rows x 1151 columns]

# %%
latest_data_2= pd.merge(latest_data,data2,on='iso_a3', how='left')

# %%
len(latest_data_2)
# Out:
# 226

# %%
latest_data_2.head()
# Out:
#        pop_est      continent            Country/Region iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI      5496.0
# 1   58005463.0         Africa                  Tanzania    TZA     63177.0
# 2     603253.0         Africa                 W. Sahara    ESH       907.0
# 3   37589262.0  North America                    Canada    CAN   1736425.0
# 4  328239523.0  North America  United States of America    USA  21433226.0
#
#                                             geometry         Lat         Long  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  -17.713400   178.065000
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...   -6.369028    34.888822
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...         NaN          NaN
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...  708.855600 -1202.597900
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...         NaN          NaN
#
#    1/22/20_x  1/23/20_x  ...    2/28/23_y     3/1/23_y     3/2/23_y  \
# 0        0.0        0.0  ...          NaN          NaN          NaN
# 1        0.0        0.0  ...          NaN          NaN          NaN
# 2        NaN        NaN  ...          NaN          NaN          NaN
# 3        0.0        2.0  ...          NaN          NaN          NaN
# 4        NaN        NaN  ...  102237507.0  102327472.0  102382876.0
#
#       3/3/23_y     3/4/23_y     3/5/23_y     3/6/23_y     3/7/23_y  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4  102441311.0  102443109.0  102438849.0  102447202.0  102482477.0
#
#       3/8/23_y     3/9/23_y
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4  102546941.0  102593407.0
#
# [5 rows x 2294 columns]

# %%
# plot coloring counties by number of confirmed cases
fig, ax = plt.subplots(figsize=(12, 8))
latest_data_2.plot(ax=ax, column='3/9/23_x', legend=True, legend_kwds={'label': '# confimed cases', 'orientation':'horizontal'})
latest_data_2.plot(ax=ax, column='3/9/23_y')

# label the counties
# for x,y,Country in zip(latest_data['Lat'], latest_data['Long'],latest_data['Country/Region']): ax.text(x,y, Country, color='black',size=5)
ax.set_title('Confirmed COVID-19 cases countrywise as of 3/9/23')
ax.set_xlabel('Latitude'); ax.set_ylabel('Longitude');

# %%
# plot coloring counties by number of confirmed cases
fig, ax = plt.subplots(figsize=(12, 8))
latest_data.plot(ax=ax, column='1/22/20', legend=True, legend_kwds={'label': '# confimed cases', 'orientation':'horizontal'}) #
# label the counties
# for x,y,Country in zip(latest_data['Lat'], latest_data['Long'],latest_data['Country/Region']): ax.text(x,y, Country, color='black',size=5)
ax.set_title('Confirmed COVID-19 cases countrywise as of 1/22/20')
ax.set_xlabel('Latitude'); ax.set_ylabel('Longitude');

# %% [markdown]
# ##Animation

# %%
# !pip install celluloid

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation
from celluloid import Camera
