# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
cd
# Out:
# /root

# %%
# metadata file (small file)
tm = pd.read_csv('/content/metadata_large_bikedata.csv')
# data file (large file)
td = pd.read_csv('/content/large_bikedata (1).csv')
td.head() # it displays the first few rows of the td
# Out:
#    index        id           start_time             end_time measure_period  \
# 0      0  36586735  2015-08-09 08:00:00  2015-08-09 08:15:00        0:15:00
# 1      1  36586736  2015-08-09 08:15:00  2015-08-09 08:30:00        0:15:00
# 2      2  36586737  2015-08-09 08:30:00  2015-08-09 08:45:00        0:15:00
# 3      3  36586738  2015-08-09 08:45:00  2015-08-09 09:00:00        0:15:00
# 4      4  36586739  2015-08-09 09:00:00  2015-08-09 09:15:00        0:15:00
#
#    volume  flow_detector_id
# 0       0              1903
# 1       0              1903
# 2       0              1903
# 3       0              1903
# 4       0              1903

# %%
tm
# Out:
#         Column Name Data Type                                Description
# 0             index     int64                      Index for each record
# 1                id     int64          Unique identifier for each record
# 2        start_time    object  Start timestamp of the measurement period
# 3          end_time    object    End timestamp of the measurement period
# 4    measure_period    object         Duration of the measurement period
# 5            volume     int64                             Volume of data
# 6  flow_detector_id     int64                    ID of the flow detector

# %%
len(td)
# Out:
# 324705

# %%
td.tail() # last few rows of the td
# Out:
#          index        id           start_time             end_time  \
# 324700  324700  36911435  2020-04-30 07:00:00  2020-04-30 07:15:00
# 324701  324701  36911436  2020-04-30 07:15:00  2020-04-30 07:30:00
# 324702  324702  36911437  2020-04-30 07:30:00  2020-04-30 07:45:00
# 324703  324703  36911438  2020-04-30 05:45:00  2020-04-30 06:00:00
# 324704  324704  36911439  2020-04-30 06:00:00  2020-04-30 06:15:00
#
#        measure_period  volume  flow_detector_id
# 324700        0:15:00       0              1903
# 324701        0:15:00       0              1903
# 324702        0:15:00       0              1903
# 324703        0:15:00       4              1905
# 324704        0:15:00       0              1903

# %%
dif = pd.to_datetime(td['end_time']) -pd.to_datetime(td['start_time'])
(dif == dif[0]).all()
# Out:
# True

# %%
td = td.rename(columns={'start_time':'time'}).drop(columns=['end_time','measure_period', 'id'])

# %%
tm.T.loc[['detector_description', 'flow_detector_id', 'detector_make','detector_name', 'facility_description'], :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-b25789ce3d8a> in <cell line: 1>()
# ----> 1 tm.T.loc[['detector_description', 'flow_detector_id', 'detector_make','detector_name', 'facility_description'], :]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...
